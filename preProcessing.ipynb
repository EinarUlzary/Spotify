# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
import pycountry_convert as pc
import numpy as np
import datetime


# %store -r Spo_Data

Spo_Data.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       [&#39;Carl Woitschach&#39;]         0.708
# 1         0.994  [&#39;Robert Schumann&#39;, &#39;Vladimir Horowitz&#39;]         0.379
# 2         0.604                   [&#39;Seweryn Goszczyński&#39;]         0.749
# 3         0.995                      [&#39;Francisco Canaro&#39;]         0.781
# 4         0.990  [&#39;Frédéric Chopin&#39;, &#39;Vladimir Horowitz&#39;]         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
# ...

# %%
Spo_Data.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# day                 0
# month               0
# dtype: int64

# %%
Spo_Data['day'] = pd.DatetimeIndex(Spo_Data['release_date']).day
Spo_Data['month'] = pd.DatetimeIndex(Spo_Data['release_date']).month
Spo_Data
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       [&#39;Carl Woitschach&#39;]         0.708
# 1             0.9940  [&#39;Robert Schumann&#39;, &#39;Vladimir Horowitz&#39;]         0.379
# 2             0.6040                   [&#39;Seweryn Goszczyński&#39;]         0.749
# 3             0.9950                      [&#39;Francisco Canaro&#39;]         0.781
# 4             0.9900  [&#39;Frédéric Chopin&#39;, &#39;Vladimir Horowitz&#39;]         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    [&#39;DripReport&#39;, &#39;Tyga&#39;]         0.875
# 169905        0.0167        [&#39;Leon Bridges&#39;, &#39;Terrace Martin&#39;]         0.719
# 169906        0.5380                     [&#39;Kygo&#39;, &#39;Oh Wonder&#39;]         0.514
# 169907        0.0714             [&#39;Cash Cash&#39;, &#39;Andy Grammer&#39;]         0.646
# ...

# %%
Spo_Clean_Data=Spo_Data.drop(['id','name' , 'release_date'], axis=1)
Spo_Clean_Data
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       [&#39;Carl Woitschach&#39;]         0.708
# 1             0.9940  [&#39;Robert Schumann&#39;, &#39;Vladimir Horowitz&#39;]         0.379
# 2             0.6040                   [&#39;Seweryn Goszczyński&#39;]         0.749
# 3             0.9950                      [&#39;Francisco Canaro&#39;]         0.781
# 4             0.9900  [&#39;Frédéric Chopin&#39;, &#39;Vladimir Horowitz&#39;]         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    [&#39;DripReport&#39;, &#39;Tyga&#39;]         0.875
# 169905        0.0167        [&#39;Leon Bridges&#39;, &#39;Terrace Martin&#39;]         0.719
# 169906        0.5380                     [&#39;Kygo&#39;, &#39;Oh Wonder&#39;]         0.514
# 169907        0.0714             [&#39;Cash Cash&#39;, &#39;Andy Grammer&#39;]         0.646
# ...

# %%
labelencoder = LabelEncoder()
Spo_Clean_Data['artists'] = labelencoder.fit_transform(Spo_Data['artists'])
Spo_Clean_Data
# Out:
#         acousticness  artists  danceability  duration_ms  energy  explicit  \
# 0             0.9950     4880         0.708       158648  0.1950         0
# 1             0.9940    25163         0.379       282133  0.0135         0
# 2             0.6040    26351         0.749       104300  0.2200         0
# 3             0.9950     9738         0.781       180760  0.1300         0
# 4             0.9900    10245         0.210       687733  0.2040         0
# ...              ...      ...           ...          ...     ...       ...
# 169904        0.1730     8004         0.875       163800  0.4430         1
# 169905        0.0167    17559         0.719       167468  0.3850         0
# 169906        0.5380    16987         0.514       180700  0.5390         0
# 169907        0.0714     5031         0.646       167308  0.7610         0
# 169908        0.1090    13224         0.512       214787  0.4280         0
#
# ...

# %%
Spo_Clean_Data['tempo'] = (Spo_Clean_Data['tempo']-Spo_Clean_Data['tempo'].min()) / (Spo_Clean_Data['tempo'].max()-Spo_Clean_Data['tempo'].min())
Spo_Clean_Data['loudness'] = (Spo_Clean_Data['loudness']-Spo_Clean_Data['loudness'].min()) / (Spo_Clean_Data['loudness'].max()-Spo_Clean_Data['loudness'].min())
Spo_Clean_Data['duration_ms'] = (Spo_Clean_Data['duration_ms']-Spo_Clean_Data['duration_ms'].min()) / (Spo_Clean_Data['duration_ms'].max()-Spo_Clean_Data['duration_ms'].min())
Spo_Clean_Data['popularity'] = (Spo_Clean_Data['popularity']-Spo_Clean_Data['popularity'].min()) / (Spo_Clean_Data['popularity'].max()-Spo_Clean_Data['popularity'].min())

# %%
Spo_Clean_Data
# Out:
#         acousticness  artists  danceability  duration_ms  energy  explicit  \
# 0             0.9950     4880         0.708     0.028442  0.1950         0
# 1             0.9940    25163         0.379     0.051316  0.0135         0
# 2             0.6040    26351         0.749     0.018374  0.2200         0
# 3             0.9950     9738         0.781     0.032538  0.1300         0
# 4             0.9900    10245         0.210     0.126450  0.2040         0
# ...              ...      ...           ...          ...     ...       ...
# 169904        0.1730     8004         0.875     0.029396  0.4430         1
# 169905        0.0167    17559         0.719     0.030076  0.3850         0
# 169906        0.5380    16987         0.514     0.032527  0.5390         0
# 169907        0.0714     5031         0.646     0.030046  0.7610         0
# 169908        0.1090    13224         0.512     0.038841  0.4280         0
#
# ...

# %%
# %store Spo_Clean_Data
# Out:
# Stored &#39;Spo_Clean_Data&#39; (DataFrame)
